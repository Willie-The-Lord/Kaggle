# %%
import pandas as pd

df = pd.read_excel('C:/Users/User/Desktop/SurveyData.xlsx') #Random Generate Data
df
# Out:
#     ID             Name  Age Gender                           Email  \
# 0    0  Kristin Stanley   25      M               6ign@logitech.com
# 1    1   Rianna Merrill   45      F   ousmansabir.co.p@logitech.com
# 2    2   Huseyin Magana   30      F  isweet.shery.lad6@logitech.com
# 3    3       Ezmae Chen   32      M        vsuellem.sa@logitech.com
# 4    4  Jamila Connelly   18      F            alanae2@logitech.com
# 5    5    Usmaan Castro   27      M     emhamad.amr.3d@logitech.com
# 6    6    Finbar Torres   50      M   rhacer.redsea.9l@logitech.com
# 7    7   Brandan Allman   26      M       hiq.mahmmadr@logitech.com
# 8    8      Avani Povey   28      M               xahz@logitech.com
# 9    9      Isra Vargas   55      M        gfahad.desx@logitech.com
# 10  10     Haider Roach   48      M           hayoub.8@logitech.com
# 11  11      Kaylen Berg   27      M     udakhanothman6@logitech.com
# 12  12        Aine Wolf   26      F       aandre-bandm@logitech.com
# ...

# %%
df.sort_values(by='Name')
# Out:
#     ID             Name  Age Gender                           Email  \
# 12  12        Aine Wolf   26      F       aandre-bandm@logitech.com
# 14  14      Aronas Kane   33      F              hjeta@logitech.com
# 8    8      Avani Povey   28      M               xahz@logitech.com
# 7    7   Brandan Allman   26      M       hiq.mahmmadr@logitech.com
# 3    3       Ezmae Chen   32      M        vsuellem.sa@logitech.com
# 6    6    Finbar Torres   50      M   rhacer.redsea.9l@logitech.com
# 10  10     Haider Roach   48      M           hayoub.8@logitech.com
# 2    2   Huseyin Magana   30      F  isweet.shery.lad6@logitech.com
# 9    9      Isra Vargas   55      M        gfahad.desx@logitech.com
# 4    4  Jamila Connelly   18      F            alanae2@logitech.com
# 11  11      Kaylen Berg   27      M     udakhanothman6@logitech.com
# 0    0  Kristin Stanley   25      M               6ign@logitech.com
# 13  13   Rachelle Coles   28      F  wmohamedr.weemouz@logitech.com
# ...

# %%
df.sort_values(by=['Age','Gender'])
# Out:
#     ID             Name  Age Gender                           Email  \
# 4    4  Jamila Connelly   18      F            alanae2@logitech.com
# 0    0  Kristin Stanley   25      M               6ign@logitech.com
# 12  12        Aine Wolf   26      F       aandre-bandm@logitech.com
# 7    7   Brandan Allman   26      M       hiq.mahmmadr@logitech.com
# 5    5    Usmaan Castro   27      M     emhamad.amr.3d@logitech.com
# 11  11      Kaylen Berg   27      M     udakhanothman6@logitech.com
# 13  13   Rachelle Coles   28      F  wmohamedr.weemouz@logitech.com
# 8    8      Avani Povey   28      M               xahz@logitech.com
# 2    2   Huseyin Magana   30      F  isweet.shery.lad6@logitech.com
# 3    3       Ezmae Chen   32      M        vsuellem.sa@logitech.com
# 14  14      Aronas Kane   33      F              hjeta@logitech.com
# 15  15       Rogan Gray   37      M          jreal_32c@logitech.com
# 1    1   Rianna Merrill   45      F   ousmansabir.co.p@logitech.com
# ...

# %%
df.sort_values(
...     by="Age",
...     ascending=False,
...     kind="mergesort"
... )
# Out:
#     ID             Name  Age Gender                           Email  \
# 9    9      Isra Vargas   55      M        gfahad.desx@logitech.com
# 6    6    Finbar Torres   50      M   rhacer.redsea.9l@logitech.com
# 10  10     Haider Roach   48      M           hayoub.8@logitech.com
# 1    1   Rianna Merrill   45      F   ousmansabir.co.p@logitech.com
# 15  15       Rogan Gray   37      M          jreal_32c@logitech.com
# 14  14      Aronas Kane   33      F              hjeta@logitech.com
# 3    3       Ezmae Chen   32      M        vsuellem.sa@logitech.com
# 2    2   Huseyin Magana   30      F  isweet.shery.lad6@logitech.com
# 8    8      Avani Povey   28      M               xahz@logitech.com
# 13  13   Rachelle Coles   28      F  wmohamedr.weemouz@logitech.com
# 5    5    Usmaan Castro   27      M     emhamad.amr.3d@logitech.com
# 11  11      Kaylen Berg   27      M     udakhanothman6@logitech.com
# 7    7   Brandan Allman   26      M       hiq.mahmmadr@logitech.com
# ...

# %%
df.sort_values(
...     by=["Age", "Gender", "Office Location"],
...     ascending=[True, True, False]
... )[["Age", "Gender", "Office Location"]]
# Out:
#     Age Gender Office Location
# 4    18      F       Hong Kong
# 0    25      M   San Francisco
# 12   26      F   San Francisco
# 7    26      M       Hong Kong
# 5    27      M   San Francisco
# 11   27      M   San Francisco
# 13   28      F       Hong Kong
# 8    28      M   San Francisco
# 2    30      F       Hong Kong
# 3    32      M         Hsinchu
# 14   33      F         Hsinchu
# 15   37      M   San Francisco
# 1    45      F         Hsinchu
# 10   48      M       Hong Kong
# 6    50      M         Hsinchu
# 9    55      M         Hsinchu

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    Office Location             Name  ID Gender  \
# 0    San Francisco  Kristin Stanley   0      M
# 1          Hsinchu   Rianna Merrill   1      F
# 2        Hong Kong   Huseyin Magana   2      F
# 3          Hsinchu       Ezmae Chen   3      M
# 4        Hong Kong  Jamila Connelly   4      F
# 5    San Francisco    Usmaan Castro   5      M
# 6          Hsinchu    Finbar Torres   6      M
# 7        Hong Kong   Brandan Allman   7      M
# 8    San Francisco      Avani Povey   8      M
# 9          Hsinchu      Isra Vargas   9      M
# 10       Hong Kong     Haider Roach  10      M
# 11   San Francisco      Kaylen Berg  11      M
# 12   San Francisco        Aine Wolf  12      F
# 13       Hong Kong   Rachelle Coles  13      F
# 14         Hsinchu      Aronas Kane  14      F
# 15   San Francisco       Rogan Gray  15      M
#
#                              Email  Age
# 0                6ign@logitech.com   25
# 1    ousmansabir.co.p@logitech.com   45
# ...
